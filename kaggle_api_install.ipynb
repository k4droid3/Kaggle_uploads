# %%
from google.colab import drive
drive.mount("/content/drive")

# !pip3 install kaggle
# !cp /content/drive/'My Drive'/ML/kaggle_binary /usr/local/bin/kaggle
# !mkdir /root/.kaggle
# !cp /content/drive/'My Drive'/ML/kaggle.json /root/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json

drive.flush_and_unmount()
# Out:
# Mounted at /content/drive

# %%
# !kaggle competitions list
# Out:
# ref                                            deadline             category            reward  teamCount  userHasEntered
# ---------------------------------------------  -------------------  ---------------  ---------  ---------  --------------
# digit-recognizer                               2030-01-01 00:00:00  Getting Started  Knowledge       2336           False
# titanic                                        2030-01-01 00:00:00  Getting Started  Knowledge      16482            True
# house-prices-advanced-regression-techniques    2030-01-01 00:00:00  Getting Started  Knowledge       5314           False
# imagenet-object-localization-challenge         2029-12-31 07:00:00  Research         Knowledge         57           False
# google-quest-challenge                         2020-02-10 23:59:00  Featured           $25,000        139           False
# tensorflow2-question-answering                 2020-01-22 23:59:00  Featured           $50,000        696           False
# data-science-bowl-2019                         2020-01-22 23:59:00  Featured          $160,000       1319           False
# pku-autonomous-driving                         2020-01-21 23:59:00  Featured           $25,000        366           False
# competitive-data-science-predict-future-sales  2019-12-31 23:59:00  Playground           Kudos       4934           False
# ashrae-energy-prediction                       2019-12-19 23:59:00  Featured           $25,000       2616           False
# Kannada-MNIST                                  2019-12-17 23:59:00  Playground       Knowledge        873           False
# bigquery-geotab-intersection-congestion        2019-12-12 23:59:00  Playground           Kudos        398           False
# cat-in-the-dat                                 2019-12-09 23:59:00  Playground            Swag       1171           False
# kaggle-survey-2019                             2019-12-02 23:59:00  Analytics          $30,000          0           False
# nfl-big-data-bowl-2020                         2019-11-27 23:59:00  Featured           $75,000       1910           False
# understanding_cloud_organization               2019-11-18 23:59:00  Research           $10,000       1538           False
# rsna-intracranial-hemorrhage-detection         2019-11-13 23:59:00  Featured           $25,000       1345           False
# 3d-object-detection-for-autonomous-vehicles    2019-11-12 23:59:00  Featured           $25,000        549           False
# severstal-steel-defect-detection               2019-10-24 23:59:00  Featured          $120,000       2433           False
# kuzushiji-recognition                          2019-10-14 23:59:00  Playground         $15,000        293           False

# %%
# !kaggle datasets list
# Out:
# ref                                                      title                                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# rajeevw/ufcdata                                          UFC-Fight historical data from 1993 to 2019          3MB  2019-07-05 09:58:02          10167        352  0.9705882
# gustavomodelli/forest-fires-in-brazil                    Forest Fires in Brazil                              31KB  2019-08-24 16:09:16          15528        359  0.7647059
# akhilv11/border-crossing-entry-data                      Border Crossing Entry Data                           4MB  2019-08-21 14:51:34           6456        158  0.8235294
# tristan581/17k-apple-app-store-strategy-games            17K Mobile Strategy Games                            8MB  2019-08-26 08:22:16          12973        461  0.9411765
# chirin/africa-economic-banking-and-systemic-crisis-data  Africa Economic, Banking and Systemic Crisis Data   14KB  2019-07-21 02:00:17           5759        174  1.0
# ruslankl/european-union-lgbt-survey-2012                 EU LGBT Survey                                     610KB  2019-07-19 11:15:25           2267         89  1.0
# kapilverma/hindi-bible                                   Hindi Bible                                          5MB  2019-09-07 18:04:35            474         35  1.0
# shuyangli94/food-com-recipes-and-user-interactions       Food.com Recipes and Interactions                  267MB  2019-11-08 01:18:21           4593        150  0.8235294
# irinachuchueva/russian-wholesale-electricity-market      Russian Wholesale Electricity Market                 1MB  2019-10-09 08:20:57           1081         34  0.9705882
# brkurzawa/us-breweries                                   US Breweries                                        76KB  2019-10-02 03:15:27           3060         70  0.9117647
# grikomsn/amazon-cell-phones-reviews                      Amazon Cell Phones Reviews                          10MB  2019-09-29 02:26:48           4041         67  1.0
# pascalbliem/european-social-survey-ess-8-ed21-201617     European Social Survey (ESS) 8 ed2.1 (2016/17)      10MB  2019-09-29 07:30:37           1083         32  0.9705882
# srikantsahu/co2-and-ghg-emission-data                    CO2 and GHG emission data                           91KB  2019-09-26 20:10:59           2705         72  0.9705882
# jojoker/singapore-airbnb                                 Singapore Airbnb                                   350KB  2019-09-25 22:05:44           3444         54  0.7647059
# hmavrodiev/sofia-air-quality-dataset                     Sofia air quality dataset                            3GB  2019-09-14 05:48:09           1996         50  0.88235295
# smid80/canadian-federal-election-results-timeseries      Canadian Federal Election Results (Timeseries)      18MB  2019-10-09 11:08:29           1019         34  1.0
# mabusalah/brent-oil-prices                               Brent Oil Prices                                    38KB  2019-10-14 12:31:05           2545         53  1.0
# nitinsss/military-expenditure-of-countries-19602019      Military Spending of Countries (1960-2019)          55KB  2019-10-10 12:17:37           4408        125  1.0
# hmavrodiev/london-bike-sharing-dataset                   London bike sharing dataset                        165KB  2019-10-10 12:49:37           5154         97  1.0
# valentynsichkar/traffic-signs-preprocessed               Traffic Signs Preprocessed                           4GB  2019-08-31 18:22:11           1939         68  1.0

# %%
# !kaggle datasets --help
# Out:
# usage: kaggle datasets [-h]
#                        {list,files,download,create,version,init,metadata,status}
#                        ...
#
# optional arguments:
#   -h, --help            show this help message and exit
#
# commands:
#   {list,files,download,create,version,init,metadata,status}
#     list                List available datasets
#     files               List dataset files
#     download            Download dataset files
#     create              Create a new dataset
#     version             Create a new dataset version
#     init                Initialize metadata file for dataset creation
#     metadata            Download metadata about a dataset
#     status              Get the creation status for a dataset
